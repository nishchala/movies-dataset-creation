# %% [markdown]
# # <font color=blue>Movie-Novels Dataset</font>

# %% [markdown]
# ##  Introduction

# %% [markdown]
# This notebook creates a custom dataset of books and movies which are based on the books. Kaggle IMDB dataset is used for getting the movies data and corresponding books information is obtained from the google books store with the help of google books API. This notebook demonstrates the tasks of acquiring, extracting, cleaning data for creating a dataset with relevant information.
#
# The Dataset provides following information about books and movies -
#
#     - Books: which category section book is located,the publish date of the books and author name of books
#     - Movies: indicates the director of the movie, the runtime time of the movie, when the movies was released and the rating of the movie and what genre does the movie fall into.
#
# The final dataset can be used in the analysis such as - Finding trends in popularity of the movies that were based on novels in the last 10 years

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import re
import csv, json
import urllib.request
import requests
import time
from pandas import DataFrame
from pprint import pprint

# %% [markdown]
# ## Reading movie datasets

# %% [markdown]
# The movie data was gathered from the IMDb on Kaggle. The IMDB is a popular movie website and it combines movie plot description, ratings,reviews, release dates, and many more aspects. The movie data has been scraped from the publicly available website https://www.imdb.com on January 1, 2020. The movies dataset includes 85,855 movies from year 1894 to 2020.

# %% [markdown]
# It contain information about the keywords and tagline indicate that these movies were based on or inspired by the books.

# %%
movies = pd.read_csv("data/movies.csv")
movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline  ...  \
# 0              The park is open.  ...
# 1             What a Lovely Day.  ...
# 2     One Choice Can Destroy You  ...
# 3  Every generation has a story.  ...
# 4            Vengeance Hits Home  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...   2015-05-13       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...   2015-03-18       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot   2015-12-15       5292
# 4  Universal Pictures|Original Film|Media Rights ...   2015-04-01       2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09
#
# [5 rows x 21 columns]

# %%
book_based_movies = movies[["id", "original_title", "keywords", "tagline"]].reset_index(drop = True)
book_based_movies.head(10)
# Out:
#        id                original_title  \
# 0  135397                Jurassic World
# 1   76341            Mad Max: Fury Road
# 2  262500                     Insurgent
# 3  140607  Star Wars: The Force Awakens
# 4  168259                     Furious 7
# 5  281957                  The Revenant
# 6   87101            Terminator Genisys
# 7  286217                   The Martian
# 8  211672                       Minions
# 9  150540                    Inside Out
#
#                                             keywords  \
# 0  monster|dna|tyrannosaurus rex|velociraptor|island
# 1   future|chase|post-apocalyptic|dystopia|australia
# 2  based on novel|revolution|dystopia|sequel|dyst...
# 3              android|spaceship|jedi|space opera|3d
# 4                car race|speed|revenge|suspense|car
# 5  father-son relationship|rape|based on novel|mo...
# 6  saving the world|artificial intelligence|cybor...
# 7        based on novel|mars|nasa|isolation|botanist
# 8  assistant|aftercreditsstinger|duringcreditssti...
# 9       dream|cartoon|imaginary friend|animation|kid
#
#                                            tagline
# 0                                The park is open.
# 1                               What a Lovely Day.
# 2                       One Choice Can Destroy You
# 3                    Every generation has a story.
# 4                              Vengeance Hits Home
# 5  (n. One who has returned, as if from the dead.)
# 6                                 Reset the future
# 7                                   Bring Him Home
# 8     Before Gru, they had a history of bad bosses
# 9         Meet the little voices inside your head.

# %% [markdown]
# #### <font color=darkblue>Searching for keywords in the Keywords column for novel based movies</font>

# %%
def search_book_keywords(keywords):
    try:
        match = re.search("(\|{0,1}[\w\s]*(book|novel)[\w\s]*\|{0,1})", keywords)
        if match:
            return match.group(0)
        else:
            return None
    except TypeError:
        return None
    
phrases_book_novel = set()
for data in set(book_based_movies["keywords"].tolist()):
    phrases = search_book_keywords(data)
    phrases_book_novel.add(phrases)

print(phrases_book_novel)
# Out:
# {'|book burning|', '|novelist', 'comic book|', 'bookshop|', '|novelist|', '|based on comic book', 'based on novel', 'based on novel|', None, 's book|', 'book store', '|based on graphic novel|', '|cookbook|', '|comic book artist|', '|based on comic book|', 'reference to the book of revelation', '|tell all novel|', 's book', '|book signing|', '|magic book|', 'plagiarized book|', '|based on novel', 'based on graphic novel|', '|yearbook|', 'book|', '|bookshop|', '|comic book', '|notebook|', '|phone book|', 'motivational book', '|based on novel|', '|comic book|', '|based on young adult book', '|book|'}

# %% [markdown]
# #### <font color=darkblue>Searching for novel based movies based on the keywords</font>

# %%
def book_based_movie(keywords):
    try:
        match1 = re.search("(\|{0,1}based[\w\s]*(book|novel)\|{0,1})", keywords)
        match2 = re.search("(\|{0,1}inspired[\w\s]*novel\|{0,1})", keywords)
        if match1 or match2:
            return True
        else:
            return False
    except TypeError:
        return None
    
book_based_movies["isNovelBased_0"] = book_based_movies["keywords"].apply(book_based_movie)  
book_based_movies.head()
# Out:
#        id                original_title  \
# 0  135397                Jurassic World
# 1   76341            Mad Max: Fury Road
# 2  262500                     Insurgent
# 3  140607  Star Wars: The Force Awakens
# 4  168259                     Furious 7
#
#                                             keywords  \
# 0  monster|dna|tyrannosaurus rex|velociraptor|island
# 1   future|chase|post-apocalyptic|dystopia|australia
# 2  based on novel|revolution|dystopia|sequel|dyst...
# 3              android|spaceship|jedi|space opera|3d
# 4                car race|speed|revenge|suspense|car
#
#                          tagline isNovelBased_0
# 0              The park is open.          False
# 1             What a Lovely Day.          False
# 2     One Choice Can Destroy You           True
# 3  Every generation has a story.          False
# 4            Vengeance Hits Home          False

# %% [markdown]
# #### <font color=darkblue> Searching for keywords in the tagline column for novel based movies </font>

# %%
def search_book_tagline(tagline):
    try:
        match = re.search("(.*(book|novel).*)", tagline)
        if match:
            return match.group(0)
        else:
            return None
    except TypeError:
        return None
    
phrases_book_novel_1 = set()
for data in set(book_based_movies["tagline"].tolist()):
    phrases = search_book_tagline(data)
    phrases_book_novel_1.add(phrases)

print(phrases_book_novel_1)
# Out:
# {"It's the oldest con in the book.", 'Based on the best-selling novel', "He wrote the book on life's big questions. But the truth is he hasn't got a clue.", 'Every book has a life of its own.', "From the book that's an American tradition… from the smash-hit Broadway show… the entertainment of the year!", 'That humble radiant terrific book is now a humble radiant terrific movie.', 'Weird sex · Obsession · Comic books', 'Based on the novel of Chico Xavier', None, 'The most beloved Pulitzer Prize book now comes vividly alive on the screen!', "Don't judge a book by its hair color!", 'A true story based on the award-winning book by Tobias Wolff.', 'Where her book ended, their story began.', "I've decided to go on tour and support my new book, Uganda Be Kidding Me. I think we all know how much I love the sound of my own voice!", 'Love goes toward love as schoolboys from their books', 'The #1 novel of the year - now a motion picture!', 'Based on the novel by Henry James', "You don't have to know the books to be in the club.", "Charlie Kaufman writes the way he lives... With Great Difficulty. His Twin Brother Donald Lives the way he writes... with foolish abandon. Susan writes about life... But can't live it. John's life is a book... Waiting to be adapted. One story... Four Lives... A million ways it can end.", 'She wrote the book on awesomeness.', 'When it comes to getting dumped... He wrote the book.', 'They wrote the book on how not to be criminals.', 'One child, one teacher, one book and one pen can change the world.'}

# %% [markdown]
# #### <font color=darkblue> Searching for novel based movies based on the keywords </font>

# %%
def book_based_movie_1(tagline):
    try:
        match = re.search("(.*novel.*)", tagline)
        if match:
            return True
        else:
            return False
    except TypeError:
        return None
    
book_based_movies["isNovelBased_1"] = book_based_movies["tagline"].apply(book_based_movie_1)  
book_based_movies.head()
# Out:
#        id                original_title  \
# 0  135397                Jurassic World
# 1   76341            Mad Max: Fury Road
# 2  262500                     Insurgent
# 3  140607  Star Wars: The Force Awakens
# 4  168259                     Furious 7
#
#                                             keywords  \
# 0  monster|dna|tyrannosaurus rex|velociraptor|island
# 1   future|chase|post-apocalyptic|dystopia|australia
# 2  based on novel|revolution|dystopia|sequel|dyst...
# 3              android|spaceship|jedi|space opera|3d
# 4                car race|speed|revenge|suspense|car
#
#                          tagline isNovelBased_0 isNovelBased_1
# 0              The park is open.          False          False
# 1             What a Lovely Day.          False          False
# 2     One Choice Can Destroy You           True          False
# 3  Every generation has a story.          False          False
# 4            Vengeance Hits Home          False          False

# %% [markdown]
# #### <font color=darkblue> Combining both the records obtained using keywords and tagline </font>

# %%
book_based_movies["novelBased"] = book_based_movies["isNovelBased_0"] + book_based_movies["isNovelBased_1"]

book_based_movies.drop(["keywords", "tagline", "isNovelBased_0", "isNovelBased_1"], axis = 1, inplace = True)
book_based_movies.head()
# Out:
#        id                original_title novelBased
# 0  135397                Jurassic World          0
# 1   76341            Mad Max: Fury Road          0
# 2  262500                     Insurgent          1
# 3  140607  Star Wars: The Force Awakens          0
# 4  168259                     Furious 7          0

# %%
book_based_movies[book_based_movies['novelBased'] == 1]
# Out:
#            id                   original_title novelBased
# 2      262500                        Insurgent          1
# 5      281957                     The Revenant          1
# 7      286217                      The Martian          1
# 10     206647                          Spectre          1
# 23     216015             Fifty Shades of Grey          1
# ...       ...                              ...        ...
# 10667   14384                     Soldier Blue          1
# 10722   28295               I Saw What You Did          1
# 10808   40060                      The Manitou          1
# 10812   31948                   Gray Lady Down          1
# 10820   13377  How the Grinch Stole Christmas!          1
#
# [297 rows x 3 columns]

# %%
book_based_movies[book_based_movies['novelBased'] == 2]
# Out:
#           id original_title novelBased
# 10660  10671        Airport          2

# %%
movies.drop(["keywords", "tagline"], axis = 1, inplace = True)

movies = pd.merge(movies,book_based_movies,how="left",left_on=["id", "original_title"],right_on=["id", "original_title"])

movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
# 3  Thirty years after defeating the Galactic Empi...      136
# 4  Deckard Shaw seeks revenge against Dominic Tor...      137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...   2015-05-13        6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...   2015-03-18        2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot   2015-12-15        5292
# 4  Universal Pictures|Original Film|Media Rights ...   2015-04-01        2947
#
#    vote_average  release_year    budget_adj   revenue_adj novelBased
# 0           6.5          2015  1.379999e+08  1.392446e+09          0
# 1           7.1          2015  1.379999e+08  3.481613e+08          0
# 2           6.3          2015  1.012000e+08  2.716190e+08          1
# 3           7.5          2015  1.839999e+08  1.902723e+09          0
# 4           7.3          2015  1.747999e+08  1.385749e+09          0

# %% [markdown]
# #### <font color=darkblue> Dropping movies records that aren't based on novels </font>

# %%
movies.drop(movies.index[(movies["novelBased"] != 1)], axis = 0, inplace = True)

# %%
movies = movies.reset_index(drop=True)

# %%
movies.head()
# Out:
#        id    imdb_id  popularity     budget    revenue        original_title  \
# 0  262500  tt2908446   13.112507  110000000  295238201             Insurgent
# 1  281957  tt1663202    9.110700  135000000  532950503          The Revenant
# 2  286217  tt3659388    7.667400  108000000  595380321           The Martian
# 3  206647  tt2379713    6.200282  245000000  880674609               Spectre
# 4  216015  tt2322441    4.710402   40000000  569651467  Fifty Shades of Grey
#
#                                                 cast  \
# 0  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 1  Leonardo DiCaprio|Tom Hardy|Will Poulter|Domhn...
# 2  Matt Damon|Jessica Chastain|Kristen Wiig|Jeff ...
# 3  Daniel Craig|Christoph Waltz|Léa Seydoux|Ralph...
# 4  Dakota Johnson|Jamie Dornan|Jennifer Ehle|Eloi...
#
#                                           homepage  \
# 0   http://www.thedivergentseries.movie/#insurgent
# 1     http://www.foxmovies.com/movies/the-revenant
# 2      http://www.foxmovies.com/movies/the-martian
# 3      http://www.sonypictures.com/movies/spectre/
# 4  https://www.facebook.com/fiftyshadesofgreymovie
#
#                       director  \
# 0             Robert Schwentke
# 1  Alejandro González Iñárritu
# 2                 Ridley Scott
# 3                   Sam Mendes
# 4           Sam Taylor-Johnson
#
#                                             overview  runtime  \
# 0  Beatrice Prior must confront her inner demons ...      119
# 1  In the 1820s, a frontiersman, Hugh Glass, sets...      156
# 2  During a manned mission to Mars, Astronaut Mar...      141
# 3  A cryptic message from Bond’s past sends him o...      148
# 4  When college senior Anastasia Steele steps in ...      125
#
#                                genres  \
# 0  Adventure|Science Fiction|Thriller
# 1    Western|Drama|Adventure|Thriller
# 2     Drama|Adventure|Science Fiction
# 3              Action|Adventure|Crime
# 4                       Drama|Romance
#
#                                 production_companies release_date  vote_count  \
# 0  Summit Entertainment|Mandeville Films|Red Wago...   2015-03-18        2480
# 1  Regency Enterprises|Appian Way|CatchPlay|Anony...   2015-12-25        3929
# 2  Twentieth Century Fox Film Corporation|Scott F...   2015-09-30        4572
# 3                       Columbia Pictures|Danjaq|B24   2015-10-26        3254
# 4  Focus Features|Trigger Street Productions|Mich...   2015-02-11        1865
#
#    vote_average  release_year    budget_adj   revenue_adj novelBased
# 0           6.3          2015  1.012000e+08  2.716190e+08          1
# 1           7.2          2015  1.241999e+08  4.903142e+08          1
# 2           7.6          2015  9.935996e+07  5.477497e+08          1
# 3           6.2          2015  2.253999e+08  8.102203e+08          1
# 4           5.3          2015  3.679998e+07  5.240791e+08          1

# %% [markdown]
# Based on the keyword and tagline, we were able to create dataset of movies that are novel based. But there were no information on the writer for each of movies for our initial movies dataset and information was not provided in the movies.csv file. So, we used the second IMD_movies.csv to gather the author information.

# %%
moviesnewset = pd.read_csv("data/IMDb_movies.csv",low_memory=False)
moviesnewset.keys()
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
moviesnewset.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     12/26/1906    Biography, Crime, Drama        70         Australia
# 2  1911      8/19/1911                      Drama        53  Germany, Denmark
# 3  1912     11/13/1912             Drama, History       100               USA
# 4  1911       3/6/1911  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes    budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154       NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $2,250
# 2  Two men of high rank are both wooing the beaut...      5.8   188       NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $45,000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237       NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %%
moviesnewset.isna().sum()
# Out:
# imdb_title_id                0
# title                        0
# original_title               0
# year                         0
# date_published               0
# genre                        0
# duration                     0
# country                     64
# language                   833
# director                    87
# writer                    1572
# production_company        4455
# actors                      69
# description               2115
# avg_vote                     0
# votes                        0
# budget                   62145
# usa_gross_income         70529
# worlwide_gross_income    54839
# metascore                72550
# reviews_from_users        7597
# reviews_from_critics     11797
# dtype: int64

# %% [markdown]
# #### <font color=darkblue>Dropping movies that are not made in USA and not in english language </font>

# %%
moviesnewset.drop(moviesnewset.index[(moviesnewset["language"] != 'English')], axis = 0, inplace = True)
moviesnewset["CountryCheck"] = moviesnewset['country'].str.contains("USA")
moviesnewset = moviesnewset[moviesnewset["CountryCheck"] == True]
moviesnewset = moviesnewset[["original_title", "writer"]].reset_index(drop = True)
moviesnewset[['original_title','writer']]
# Out:
#                                           original_title  \
# 0                                              Cleopatra
# 1      From the Manger to the Cross; or, Jesus of Naz...
# 2                                            Richard III
# 3                                       Home, Sweet Home
# 4                                       Traffic in Souls
# ...                                                  ...
# 28380                                      Abduction 101
# 28381                                      Bulletproof 2
# 28382                                                VFW
# 28383                             The Pilgrim's Progress
# 28384                                    Coffee & Kareem
#
#                                  writer
# 0                      Victorien Sardou
# 1                         Gene Gauntier
# 2      James Keane, William Shakespeare
# 3            D.W. Griffith, H.E. Aitken
# 4                                   NaN
# ...                                 ...
# 28380      Robin Entreinger, Steve Noir
# 28381     Don Michael Paul, Rich Wilkes
# 28382     Max Brallier, Matthew McArdle
# 28383     John Bunyan, Robert Fernandez
# 28384                        Shane Mack
#
# [28385 rows x 2 columns]

# %% [markdown]
# #### <font color=darkblue> Here we are combine both dataset </font>

# %% [markdown]
# Taking the dataset that include the tagline and keywords and dataset that include author and merge them together

# %%
movies = pd.merge(movies, moviesnewset, how = "inner", left_on = "original_title", right_on = "original_title")
movies
# Out:
#          id    imdb_id  popularity     budget    revenue  \
# 0    262500  tt2908446   13.112507  110000000  295238201
# 1    281957  tt1663202    9.110700  135000000  532950503
# 2    216015  tt2322441    4.710402   40000000  569651467
# 3    294254  tt4046784    3.968891   61000000  311256926
# 4    257445  tt1051904    3.644541   58000000  150170815
# ..      ...        ...         ...        ...        ...
# 209   15613  tt0106912    0.239060   19885552   19724334
# 210     235  tt0092005    1.349043    8000000   52287000
# 211   14384  tt0066390    0.281532          0          0
# 212   28295  tt0059297    0.014759          0          0
# 213   40060  tt0077904    0.129123          0          0
#
#                      original_title  \
# 0                         Insurgent
# 1                      The Revenant
# 2              Fifty Shades of Grey
# 3    Maze Runner: The Scorch Trials
# 4                        Goosebumps
# ..                              ...
# 209                 Fire in the Sky
# 210                     Stand by Me
# 211                    Soldier Blue
# 212              I Saw What You Did
# 213                     The Manitou
#
#                                                   cast  \
# 0    Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 1    Leonardo DiCaprio|Tom Hardy|Will Poulter|Domhn...
# 2    Dakota Johnson|Jamie Dornan|Jennifer Ehle|Eloi...
# 3    Dylan O'Brien|Kaya Scodelario|Thomas Brodie-Sa...
# 4    Jack Black|Dylan Minnette|Odeya Rush|Amy Ryan|...
# ..                                                 ...
# 209  D. B. Sweeney|Robert Patrick|Craig Sheffer|Pet...
# 210  Wil Wheaton|River Phoenix|Corey Feldman|Jerry ...
# 211  Candice Bergen|Peter Strauss|Donald Pleasence|...
# 212  Joan Crawford|John Ireland|Leif Erickson|Sara ...
# 213  Tony Curtis|Michael Ansara|Susan Strasberg|Ste...
#
#                                             homepage  \
# 0     http://www.thedivergentseries.movie/#insurgent
# 1       http://www.foxmovies.com/movies/the-revenant
# 2    https://www.facebook.com/fiftyshadesofgreymovie
# 3                        http://mazerunnermovies.com
# 4                   http://www.goosebumps-movie.com/
# ..                                               ...
# 209                                              NaN
# 210                                              NaN
# 211                                              NaN
# 212                                              NaN
# 213                                              NaN
#
#                         director  \
# 0               Robert Schwentke
# 1    Alejandro González Iñárritu
# 2             Sam Taylor-Johnson
# 3                       Wes Ball
# 4                  Rob Letterman
# ..                           ...
# 209             Robert Lieberman
# 210                   Rob Reiner
# 211                 Ralph Nelson
# 212               William Castle
# 213              William Girdler
#
#                                               overview  ...  \
# 0    Beatrice Prior must confront her inner demons ...  ...
# 1    In the 1820s, a frontiersman, Hugh Glass, sets...  ...
# 2    When college senior Anastasia Steele steps in ...  ...
# 3    Thomas and his fellow Gladers face their great...  ...
# 4    A teenager teams up with the daughter of young...  ...
# ..                                                 ...  ...
# 209  A group of men who were clearing bush for the ...  ...
# 210  The film's name comes from the song "Stand By ...  ...
# 211  After a cavalry group is massacred by the Chey...  ...
# 212  When two teenagers make prank phone calls to s...  ...
# 213  A psychic's girlfriend finds out that a lump o...  ...
#
#                                  genres  \
# 0    Adventure|Science Fiction|Thriller
# 1      Western|Drama|Adventure|Thriller
# 2                         Drama|Romance
# 3       Action|Science Fiction|Thriller
# 4               Adventure|Horror|Comedy
# ..                                  ...
# 209       Drama|Horror|Thriller|Mystery
# 210                         Crime|Drama
# 211        Action|Drama|Romance|Western
# 212             Horror|Mystery|Thriller
# 213                              Horror
#
#                                   production_companies release_date  \
# 0    Summit Entertainment|Mandeville Films|Red Wago...   2015-03-18
# 1    Regency Enterprises|Appian Way|CatchPlay|Anony...   2015-12-25
# 2    Focus Features|Trigger Street Productions|Mich...   2015-02-11
# 3    Gotham Group|Temple Hill Entertainment|TSG Ent...   2015-09-09
# 4    Columbia Pictures|Original Film|Scholastic Ent...   2015-08-05
# ..                                                 ...          ...
# 209                                 Paramount Pictures   1993-03-12
# 210                                  Columbia Pictures   1986-08-07
# 211                  AVCO Embassy Pictures|Katzka-Loeb   1970-08-12
# 212                         William Castle Productions   1965-07-21
# 213  Melvin Simon Productions|Mid-America Pictures|...   1978-04-28
#
#     vote_count  vote_average  release_year    budget_adj   revenue_adj  \
# 0         2480           6.3          2015  1.012000e+08  2.716190e+08
# 1         3929           7.2          2015  1.241999e+08  4.903142e+08
# 2         1865           5.3          2015  3.679998e+07  5.240791e+08
# 3         1849           6.4          2015  5.611998e+07  2.863562e+08
# 4          600           6.2          2015  5.335998e+07  1.381571e+08
# ..         ...           ...           ...           ...           ...
# 209         49           6.4          1993  3.001664e+07  2.977329e+07
# 210        792           7.5          1986  1.591525e+07  1.040201e+08
# 211         18           7.1          1970  0.000000e+00  0.000000e+00
# 212         11           4.4          1965  0.000000e+00  0.000000e+00
# 213         10           5.8          1978  0.000000e+00  0.000000e+00
#
#      novelBased                        writer
# 0             1                 Veronica Roth
# 1             1                D. Kerry Prior
# 2             1                    E.L. James
# 3             1                 James Dashner
# 4             1                   R. L. Stine
# ..          ...                           ...
# 209           1                 Travis Walton
# 210           1  Stephen King, Raynold Gideon
# 211           1             Theodore V. Olsen
# 212           1                Ursula Curtiss
# 213           1              Graham Masterton
#
# [214 rows x 21 columns]

# %%
movies[["original_title", "writer","director","overview", "genres", "vote_average","release_year","novelBased" ]].reset_index(drop = True)
# Out:
#                      original_title                        writer  \
# 0                         Insurgent                 Veronica Roth
# 1                      The Revenant                D. Kerry Prior
# 2              Fifty Shades of Grey                    E.L. James
# 3    Maze Runner: The Scorch Trials                 James Dashner
# 4                        Goosebumps                   R. L. Stine
# ..                              ...                           ...
# 209                 Fire in the Sky                 Travis Walton
# 210                     Stand by Me  Stephen King, Raynold Gideon
# 211                    Soldier Blue             Theodore V. Olsen
# 212              I Saw What You Did                Ursula Curtiss
# 213                     The Manitou              Graham Masterton
#
#                         director  \
# 0               Robert Schwentke
# 1    Alejandro González Iñárritu
# 2             Sam Taylor-Johnson
# 3                       Wes Ball
# 4                  Rob Letterman
# ..                           ...
# 209             Robert Lieberman
# 210                   Rob Reiner
# 211                 Ralph Nelson
# 212               William Castle
# 213              William Girdler
#
#                                               overview  \
# 0    Beatrice Prior must confront her inner demons ...
# 1    In the 1820s, a frontiersman, Hugh Glass, sets...
# 2    When college senior Anastasia Steele steps in ...
# 3    Thomas and his fellow Gladers face their great...
# 4    A teenager teams up with the daughter of young...
# ..                                                 ...
# 209  A group of men who were clearing bush for the ...
# 210  The film's name comes from the song "Stand By ...
# 211  After a cavalry group is massacred by the Chey...
# 212  When two teenagers make prank phone calls to s...
# 213  A psychic's girlfriend finds out that a lump o...
#
#                                  genres  vote_average  release_year novelBased
# 0    Adventure|Science Fiction|Thriller           6.3          2015          1
# 1      Western|Drama|Adventure|Thriller           7.2          2015          1
# 2                         Drama|Romance           5.3          2015          1
# 3       Action|Science Fiction|Thriller           6.4          2015          1
# 4               Adventure|Horror|Comedy           6.2          2015          1
# ..                                  ...           ...           ...        ...
# 209       Drama|Horror|Thriller|Mystery           6.4          1993          1
# 210                         Crime|Drama           7.5          1986          1
# 211        Action|Drama|Romance|Western           7.1          1970          1
# 212             Horror|Mystery|Thriller           4.4          1965          1
# 213                              Horror           5.8          1978          1
#
# [214 rows x 8 columns]

# %% [markdown]
# ### For convenience we are using only 90 records for movie dataset

# %%
moviescheck = movies.iloc[0:90]

# %%
moviescheck
# Out:
#         id    imdb_id  popularity     budget    revenue  \
# 0   262500  tt2908446   13.112507  110000000  295238201
# 1   281957  tt1663202    9.110700  135000000  532950503
# 2   216015  tt2322441    4.710402   40000000  569651467
# 3   294254  tt4046784    3.968891   61000000  311256926
# 4   257445  tt1051904    3.644541   58000000  150170815
# ..     ...        ...         ...        ...        ...
# 85      13  tt0109830    6.715966   55000000  677945399
# 86   82693  tt1045658    3.931139   21000000  205738714
# 87   75780  tt0790724    2.944554   60000000  218340595
# 88   49529  tt0401729    1.588457  260000000  284139100
# 89   96724  tt1781769    1.327062          0   68929150
#
#                     original_title  \
# 0                        Insurgent
# 1                     The Revenant
# 2             Fifty Shades of Grey
# 3   Maze Runner: The Scorch Trials
# 4                       Goosebumps
# ..                             ...
# 85                    Forrest Gump
# 86         Silver Linings Playbook
# 87                    Jack Reacher
# 88                     John Carter
# 89                   Anna Karenina
#
#                                                  cast  \
# 0   Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 1   Leonardo DiCaprio|Tom Hardy|Will Poulter|Domhn...
# 2   Dakota Johnson|Jamie Dornan|Jennifer Ehle|Eloi...
# 3   Dylan O'Brien|Kaya Scodelario|Thomas Brodie-Sa...
# 4   Jack Black|Dylan Minnette|Odeya Rush|Amy Ryan|...
# ..                                                ...
# 85  Tom Hanks|Robin Wright|Gary Sinise|Mykelti Wil...
# 86  Bradley Cooper|Jennifer Lawrence|Robert De Nir...
# 87  Tom Cruise|Rosamund Pike|Richard Jenkins|David...
# 88  Taylor Kitsch|Lynn Collins|Mark Strong|Willem ...
# 89  Keira Knightley|Jude Law|Aaron Taylor-Johnson|...
#
#                                            homepage  \
# 0    http://www.thedivergentseries.movie/#insurgent
# 1      http://www.foxmovies.com/movies/the-revenant
# 2   https://www.facebook.com/fiftyshadesofgreymovie
# 3                       http://mazerunnermovies.com
# 4                  http://www.goosebumps-movie.com/
# ..                                              ...
# 85                                              NaN
# 86           http://silverliningsplaybookmovie.com/
# 87                 http://www.jackreachermovie.com/
# 88                 http://disney.go.com/johncarter/
# 89                                              NaN
#
#                        director  \
# 0              Robert Schwentke
# 1   Alejandro González Iñárritu
# 2            Sam Taylor-Johnson
# 3                      Wes Ball
# 4                 Rob Letterman
# ..                          ...
# 85              Robert Zemeckis
# 86             David O. Russell
# 87        Christopher McQuarrie
# 88               Andrew Stanton
# 89                   Joe Wright
#
#                                              overview  ...  \
# 0   Beatrice Prior must confront her inner demons ...  ...
# 1   In the 1820s, a frontiersman, Hugh Glass, sets...  ...
# 2   When college senior Anastasia Steele steps in ...  ...
# 3   Thomas and his fellow Gladers face their great...  ...
# 4   A teenager teams up with the daughter of young...  ...
# ..                                                ...  ...
# 85  A man with a low IQ has accomplished great thi...  ...
# 86  After spending eight months in a mental instit...  ...
# 87  In an innocent heartland city, five are shot d...  ...
# 88  Civil War vet John Carter is transplanted to M...  ...
# 89  Trapped in a loveless marriage, aristocrat Ann...  ...
#
#                                       genres  \
# 0         Adventure|Science Fiction|Thriller
# 1           Western|Drama|Adventure|Thriller
# 2                              Drama|Romance
# 3            Action|Science Fiction|Thriller
# 4                    Adventure|Horror|Comedy
# ..                                       ...
# 85                      Comedy|Drama|Romance
# 86                      Drama|Comedy|Romance
# 87                      Crime|Drama|Thriller
# 88  Action|Adventure|Fantasy|Science Fiction
# 89                             Drama|Romance
#
#                                  production_companies release_date vote_count  \
# 0   Summit Entertainment|Mandeville Films|Red Wago...   2015-03-18       2480
# 1   Regency Enterprises|Appian Way|CatchPlay|Anony...   2015-12-25       3929
# 2   Focus Features|Trigger Street Productions|Mich...   2015-02-11       1865
# 3   Gotham Group|Temple Hill Entertainment|TSG Ent...   2015-09-09       1849
# 4   Columbia Pictures|Original Film|Scholastic Ent...   2015-08-05        600
# ..                                                ...          ...        ...
# 85                                 Paramount Pictures   1994-07-06       4856
# 86                              The Weinstein Company   2012-09-08       3317
# 87  Paramount Pictures|Mutual Film Company|Skydanc...   2012-12-20       2281
# 88                               Walt Disney Pictures   2012-03-07       1479
# 89  Universal Pictures|Focus Features|Working Titl...   2012-09-06        415
#
#     vote_average  release_year    budget_adj   revenue_adj  novelBased  \
# 0            6.3          2015  1.012000e+08  2.716190e+08           1
# 1            7.2          2015  1.241999e+08  4.903142e+08           1
# 2            5.3          2015  3.679998e+07  5.240791e+08           1
# 3            6.4          2015  5.611998e+07  2.863562e+08           1
# 4            6.2          2015  5.335998e+07  1.381571e+08           1
# ..           ...           ...           ...           ...         ...
# 85           8.1          1994  8.091114e+07  9.973333e+08           1
# 86           6.9          2012  1.994463e+07  1.953992e+08           1
# 87           6.2          2012  5.698466e+07  2.073677e+08           1
# 88           6.0          2012  2.469335e+08  2.698595e+08           1
# 89           6.4          2012  0.000000e+00  6.546507e+07           1
#
#                         writer
# 0                Veronica Roth
# 1               D. Kerry Prior
# 2                   E.L. James
# 3                James Dashner
# 4                  R. L. Stine
# ..                         ...
# 85               Winston Groom
# 86               Matthew Quick
# 87                   Lee Child
# 88        Edgar Rice Burroughs
# 89  Leo Tolstoy, Clemence Dane
#
# [90 rows x 21 columns]

# %%
movies_books_titles = moviescheck['original_title'].tolist()
print(movies_books_titles)
print(len(movies_books_titles))
# Out:
# ['Insurgent', 'The Revenant', 'Fifty Shades of Grey', 'Maze Runner: The Scorch Trials', 'Goosebumps', 'Room', 'Room', 'Paper Towns', 'Mortdecai', 'The Longest Ride', 'Dark Places', 'Dark Places', 'Z for Zachariah', 'The Diary of a Teenage Girl', 'Tales of Halloween', 'And Then There Were None', 'The Maze Runner', 'Gone Girl', 'The Amazing Spider-Man 2', '300: Rise of an Empire', 'The Giver', 'Paddington', 'The Fault in Our Stars', 'Good People', 'The Boxtrolls', 'White Bird in a Blizzard', "Winter's Tale", 'Alexander and the Terrible, Horrible, No Good, Very Bad Day', 'The Scribbler', 'Every Secret Thing', 'Delirium', 'Delirium', 'Delirium', 'Delirium', 'Audrey Rose', 'The White Buffalo', 'Watchmen', 'Love and Other Impossible Pursuits', 'Me and Orson Welles', 'Walled In', 'Like Dandelion Dust', 'Alice in Wonderland', 'Alice in Wonderland', 'Alice in Wonderland', 'Alice in Wonderland', 'Alice in Wonderland', 'Alice in Wonderland', 'The Chronicles of Narnia: The Voyage of the Dawn Treader', 'Dear John', 'Charlie St. Cloud', 'Flipped', 'Flipped', 'Never Let Me Go', "My Girlfriend's Boyfriend", "My Girlfriend's Boyfriend", 'Girl, Interrupted', "The General's Daughter", 'In Dreams', 'The Shipping News', 'The Chronicles of Narnia: Prince Caspian', 'Marley & Me', "Nick and Norah's Infinite Playlist", 'The Informers', 'Winged Creatures', 'One Day', "What's Your Number?", 'The Help', 'Moneyball', 'Something Borrowed', 'The Big Year', 'Beastly', 'Diary of a Wimpy Kid: Rodrick Rules', 'Extremely Loud & Incredibly Close', 'The Smurfs', 'Blitz', 'A Dangerous Method', 'Soul Surfer', 'Wuthering Heights', 'Wuthering Heights', 'Little Birds', 'Age of the Dragons', 'Treasure Planet', 'A Walk to Remember', 'Road to Perdition', 'Auto Focus', 'Forrest Gump', 'Silver Linings Playbook', 'Jack Reacher', 'John Carter', 'Anna Karenina']
# 90

# %%
movies_books_authors = moviescheck['writer'].tolist()
print(movies_books_authors)
# Out:
# ['Veronica Roth', 'D. Kerry Prior', 'E.L. James', 'James Dashner', 'R. L. Stine', 'Kyle Henry', 'Emma Donoghue, Emma Donoghue', 'John Green', 'Kyril Bonfiglioli', 'Nicholas Sparks', 'Guy Crawford', 'Gillian Flynn', "Robert C. O'Brien", 'Phoebe Gloeckner', 'Axelle Carolyn, Dave Parker', 'Agatha Christie', 'James Dashner', 'Gillian Flynn', 'Alex Kurtzman, Roberto Orci', 'Frank Miller', 'Lois Lowry', 'Michael Bond', 'John Green', 'Marcus Sakey', 'Irena Brignull, Adam Pava', 'Laura Kasischke', 'Mark Helprin', 'Judith Viorst', 'Daniel Schaffer', 'Laura Lippman', 'Eddie Krell, Jim Loew', 'Adam Alleca', 'Jared Stanton, Thor Wixom', 'Francisco Castro, Andy Cheng', 'Frank De Felitta', 'Richard Sale, Richard Sale', 'Alan Moore', 'Ayelet Waldman', 'Robert Kaplow', 'Serge Brussolo, Rodolphe Tissot', 'Karen Kingsbury', 'Lewis Carroll', 'Lewis Carroll', 'Joseph L. Mankiewicz, William Cameron Menzies', 'Lewis Carroll', 'Lewis Carroll, Winston Hibler', 'Lewis Carroll', 'C. S. Lewis', 'Nicholas Sparks', 'Ben Sherwood', 'Wendelin Van Draanen', 'Harris Demel, Rob Greenberg', 'Roger Bax', 'Kenneth Schapiro', 'Daryn Tufts, Daryn Tufts', 'Susanna Kaysen', 'Nelson DeMille', 'Bari Wood', 'Annie Proulx', 'C. S. Lewis', 'John Grogan', 'Rachel Cohn', 'Bret Easton Ellis', 'Roy Freirich', 'David Nicholls', 'Karyn Bosnak', 'Kathryn Stockett', 'Michael Lewis', 'Emily Giffin', 'Mark Obmascik', 'Alex Flinn', 'Jeff Kinney', 'Jonathan Safran Foer', 'Peyo', 'Ken Bruen', 'Christopher Hampton', ' Bethany Hamilton', 'Charles MacArthur, Ben Hecht', 'Emily Brontë, Anne Devlin', 'Elgin James', 'McKay Daines, Gil Aglaure', 'Robert Louis Stevenson', 'Nicholas Sparks', 'Max Allan Collins, Richard Piers Rayner', 'Robert Graysmith', 'Winston Groom', 'Matthew Quick', 'Lee Child', 'Edgar Rice Burroughs', 'Leo Tolstoy, Clemence Dane']

# %% [markdown]
# ### Running google books API call

# %% [markdown]
# Google Books API allows acess to many of the operations available on Google Books website includes different features to your application. It is intended for developers who want to write applications that can interact with the Google Books API. The Google books API can be accessed by creating an google account, creating application and create your own API key. More information can be found [here](https://developers.google.com/books/docs/overview)

# %% [markdown]
# The Google Terms of Service for use of the APIs is available here: https://developer.google.com/books/terms.html.

# %% [markdown]
# Google API rate limit:
# - Queries per day : 1000
# - Queries per minute per user : 100

# %% [markdown]
# #### This is what the raw api search query call looks like:

# %%
query = "harry potter"
ap1_key = "AIzaSyC9J5_C1kJfIGejuMPkIKUmnmh2ir-5dok"
address = "https://www.googleapis.com/books/v1/volumes?" +"q="+query+"&key=" + ap1_key
resp = requests.get(address)
result = resp.json()
pprint(result)
# Out:
# {'items': [{'accessInfo': {'accessViewStatus': 'NONE',
#                            'country': 'US',
#                            'embeddable': False,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'NO_PAGES',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=eq9XvgAACAAJ&hl=&printsec=frontcover&source=gbs_api'},
#             'etag': 'ycJ1mgPV+ug',
#             'id': 'eq9XvgAACAAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': '
',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=f280CwAAQBAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=f280CwAAQBAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9781781106464',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '1781106460',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'http://books.google.com/books?id=f280CwAAQBAJ&dq=harry+potter&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 4236,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=f280CwAAQBAJ&pg=PP1&dq=harry+potter&hl=&cd=5&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2015-12-14',
#                            'publisher': 'Pottermore Publishing',
#                            'ratingsCount': 48,
#                            'readingModes': {'image': False, 'text': True},
#                            'title': 'Harry Potter: The Complete Collection '
#                                     '(1-7)'}},
#            {'accessInfo': {'accessViewStatus': 'NONE',
#                            'country': 'US',
#                            'embeddable': False,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'NO_PAGES',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=mvmGPgAACAAJ&hl=&printsec=frontcover&source=gbs_api'},
#             'etag': 'b55E3lG+PWc',
#             'id': 'mvmGPgAACAAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'Rescued from the outrageous neglect '
#                                           'of his aunt and uncle, a young boy '
#                                           'with a great destiny proves his '
#                                           'worth while attending Hogwarts '
#                                           'School for Wizards and Witches.'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/mvmGPgAACAAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['J. K. Rowling'],
#                            'averageRating': 4.5,
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/Harry_Potter_and_the_Sorcerer_s_Stone.html?hl=&id=mvmGPgAACAAJ',
#                            'categories': ['Juvenile Fiction'],
#                            'contentVersion': 'preview-1.0.0',
#                            'description': 'Rescued from the outrageous neglect '
#                                           'of his aunt and uncle, a young boy '
#                                           'with a great destiny proves his '
#                                           'worth while attending Hogwarts '
#                                           'School for Wizards and Witches.',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=mvmGPgAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=mvmGPgAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '043920352X',
#                                                     'type': 'ISBN_10'},
#                                                    {'identifier': '9780439203524',
#                                                     'type': 'ISBN_13'}],
#                            'infoLink': 'http://books.google.com/books?id=mvmGPgAACAAJ&dq=harry+potter&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 320,
#                            'previewLink': 'http://books.google.com/books?id=mvmGPgAACAAJ&dq=harry+potter&hl=&cd=6&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2000-10-01',
#                            'publisher': 'Scholastic',
#                            'ratingsCount': 1546,
#                            'readingModes': {'image': False, 'text': False},
#                            'title': "Harry Potter and the Sorcerer's Stone"}},
#            {'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'US',
#                            'embeddable': True,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'isAvailable': False},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=L18VBQAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#             'etag': '2glFRFTMqbE',
#             'id': 'L18VBQAAQBAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'country': 'US',
#                          'isEbook': False,
#                          'saleability': 'NOT_FOR_SALE'},
#             'searchInfo': {'textSnippet': 'Presents a psychological look at '
#                                           'the Harry Potter books, examining '
#                                           'such topics as what students learn '
#                                           'from Hogwarts classes, what Harry '
#                                           'and Fawkes the phoenix have in '
#                                           'common, and mental illness in the '
#                                           'wizarding world.'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/L18VBQAAQBAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Neil Mulholland'],
#                            'averageRating': 3.5,
#                            'canonicalVolumeLink': 'https://books.google.com/books/about/The_Psychology_of_Harry_Potter.html?hl=&id=L18VBQAAQBAJ',
#                            'categories': ['Literary Criticism'],
#                            'contentVersion': 'preview-1.0.0',
#                            'description': 'Presents a psychological look at '
#                                           'the Harry Potter books, examining '
#                                           'such topics as what students learn '
#                                           'from Hogwarts classes, what Harry '
#                                           'and Fawkes the phoenix have in '
#                                           'common, and mental illness in the '
#                                           'wizarding world.',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=L18VBQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=L18VBQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9781932100884',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '1932100881',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'http://books.google.com/books?id=L18VBQAAQBAJ&dq=harry+potter&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 326,
#                            'previewLink': 'http://books.google.com/books?id=L18VBQAAQBAJ&printsec=frontcover&dq=harry+potter&hl=&cd=7&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2006',
#                            'publisher': 'BenBella Books',
#                            'ratingsCount': 6,
#                            'readingModes': {'image': False, 'text': False},
#                            'subtitle': 'An Unauthorized Examination of the Boy '
#                                        'who Lived',
#                            'title': 'The Psychology of Harry Potter'}},
#            {'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'US',
#                            'embeddable': True,
#                            'epub': {'acsTokenLink': 'http://books.google.com/books/download/Harry_Potter_and_Philosophy-sample-epub.acsm?id=Gz8t2MttEQUC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                     'isAvailable': True},
#                            'pdf': {'acsTokenLink': 'http://books.google.com/books/download/Harry_Potter_and_Philosophy-sample-pdf.acsm?id=Gz8t2MttEQUC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                    'isAvailable': True},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id
#                                           'the wizarding world Gives you a new '
#                                           'perspective on Harry Potter '
#                                           'characters, plot lines, and themes '
#                                           'Makes a perfect companion to the '
#                                           'Harry Potter books and movies '
#                                           'Packed with interesting ideas and '
#                                           'insights, The Ultimate Harry Potter '
#                                           'and Philosophy is an ideal '
#                                           'companion for anyone interested in '
#                                           'unraveling the subtext and '
#                                           'exploring the greater issues at '
#                                           'work in the story.',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=lJB5DwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=lJB5DwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9780470398258',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '0470398256',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'http://books.google.com/books?id=lJB5DwAAQBAJ&dq=harry+potter&hl=&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 304,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=lJB5DwAAQBAJ&printsec=frontcover&dq=harry+potter&hl=&cd=9&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2010-09-14',
#                            'publisher': 'John Wiley & Sons',
#                            'ratingsCount': 5,
#                            'readingModes': {'image': True, 'text': False},
#                            'subtitle': 'Hogwarts for Muggles',
#                            'title': 'The Ultimate Harry Potter and '
#                                     'Philosophy'}},
#            {'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'US',
#                            'embeddable': True,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'acsTokenLink': 'http://books.google.com/books/download/The_Unofficial_Harry_Potter_Spellbook-sample-pdf.acsm?id=mdzfAAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                    'isAvailable': True},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=mdzfAAAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#             'etag': 'BBbMiReMt1E',
#             'id': 'mdzfAAAAQBAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=mdzfAAAAQBAJ&rdid=book-mdzfAAAAQBAJ&rdot=1&source=gbs_api',
#                          'country': 'US',
#                          'isEbook': True,
#                          'listPrice': {'amount': 14.95, 'currencyCode': 'USD'},
#                          'offers': [{'finskyOfferType': 1,
#                                      'giftable': True,
#                                      'listPrice': {'amountInMicros': 14950000,
#                                                    'currencyCode': 'USD'},
#                                      'retailPrice': {'amountInMicros': 14950000,
#                                                      'currencyCode': 'USD'}}],
#                          'retailPrice': {'amount': 14.95,
#                                          'currencyCode': 'USD'},
#                          'saleability': 'FOR_SALE'},
#             'searchInfo': {'textSnippet': 'Written by fifteen-year-old author '
#                                           'Duncan Levy, this extensive '
#                                           'collection of spells is not only a '
#                                           'fun treat for fans but an extensive '
#                                           'look into the magic that fuels the '
#                                           'universe of Harry Potter.'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/mdzfAAAAQBAJ',
#             'volumeInfo': {'allowAnonLogging': True,
#                            'authors': ['Duncan Levy'],
#                            'averageRating': 5,
#                            'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=mdzfAAAAQBAJ',
#                            'categories': ['Fiction'],
#                            'contentVersion': 'preview-1.0.0',
#                            'description': '<p>Author and Harry Potter fan '
#                                           'Duncan Levy recognizes that '
#                                           '“<i>Wingardium Leviosa</i>” may be '
#                                           'the most popular spell incantation '
#                                           'from the world of Harry Potter, but '
#                                           "he'd be the first to remind fans "
#                                           "that it isn't the only one.</p> "
#                                           '<p><i>The Unofficial Harry Potter '
#                                           'Spellbook</i> is a comprehensive '
#                                           'companion for fans looking to delve '
#                                           'deeper into the magical world of '
#                                           'Harry Potter. Written by '
#                                           'fifteen-year-old author Duncan '
#                                           'Levy, this extensive collection of '
#                                           'spells is not only a fun treat for '
#                                           'fans but an extensive look into the '
#                                           'magic that fuels the universe of '
#                                           'Harry Potter.</p> <p>The books of '
#                                           'Harry Potter were written by '
#                                           'British author J.K Rowling. Since '
#                                           "the first book's publication back "
#                                           'in 1997, the Hogwarts universe has '
#                                           'since taken the world by storm, '
#                                           'spawning a series of highly '
#                                           'successful films, and a whole line '
#                                           'of official and unofficial books, '
#                                           'toys, games, and clothing '
#                                           'lines.</p> <p><i>The Unofficial '
#                                           'Harry Potter Spellbook</i> takes '
#                                           'fans one step closer to the world '
#                                           'of Harry Potter by providing them '
#                                           'with a convenient and fun way of '
#                                           'finding out the different magical '
#                                           'spells that were used in the books. '
#                                           'The book covers everything from '
#                                           'hexes, jinxes, and curses, to '
#                                           'charms and healing spells. Whether '
#                                           "you're looking for a quick-read "
#                                           'magic guide or a fun addition to '
#                                           'your growing collection of Harry '
#                                           'Potter memorabilia, <i>The '
#                                           'Unofficial Harry Potter '
#                                           'Spellbook</i> is perfect for you. '
#                                           '<p><i>The Unofficial Harry Potter '
#                                           'Spellbook</i> is part of the '
#                                           'THiNKaha series whose slim and '
#                                           'handy books contain 140 '
#                                           'well-thought-out quotations '
#                                           '(tweets/ahas).',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=mdzfAAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=mdzfAAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9781616991289',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '1616991283',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'https://play.google.com/store/books/details?id=mdzfAAAAQBAJ&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 116,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.com/books?id=mdzfAAAAQBAJ&printsec=frontcover&dq=harry+potter&hl=&cd=10&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2013-09-11',
#                            'publisher': 'THiNKaha',
#                            'ratingsCount': 1,
#                            'readingModes': {'image': True, 'text': False},
#                            'subtitle': 'The Wand Chooses the Wizard',
#                            'title': 'The Unofficial Harry Potter Spellbook'}}],
#  'kind': 'books#volumes',
#  'totalItems': 1885}

# %% [markdown]
# #### Intregrating api calls with movies information and create a dataset

# %%
ap1_key = "AIzaSyC9J5_C1kJfIGejuMPkIKUmnmh2ir-5dok"
base_api_link = 'https://www.googleapis.com/books/v1/volumes?q=intitle:{}+inauthor:{}&key='+ ap1_key
book_info = []
not_found = []
for book, auth in zip(movies_books_titles, movies_books_authors):
     
    url_split = list(urllib.parse.urlsplit(base_api_link.format(book,auth)))
    url_split[3] = urllib.parse.quote(url_split[3], safe='q=&')
    url = urllib.parse.urlunsplit(url_split)
    print(url)
    
    r = requests.get(url)
    results = json.loads(r.text)
#     print(results)
    if "items" in results:
            i = 0
            volume_info = results["items"][i]
            try:
                volume_info["volumeInfo"]["title"]
            except KeyError:
                i += 1
                volume_info = results["items"][i]
            
            authors = volume_info["volumeInfo"]["authors"] if "authors" in volume_info["volumeInfo"] else  np.nan
            category = volume_info["volumeInfo"]["categories"] if "categories" in volume_info["volumeInfo"] else  np.nan
            pages = volume_info["volumeInfo"]["pageCount"] if "pageCount" in volume_info["volumeInfo"] else  np.nan
            publish_date = volume_info["volumeInfo"]["publishedDate"] if "publishedDate" in volume_info["volumeInfo"] else  np.nan
                
            book_info.append({"google_id": volume_info['id'],
            "title": volume_info["volumeInfo"]["title"],
            "author": authors, 
            "publish_date": publish_date,
            "category": category,
            "pages": pages})
    else: 
            not_found.append(book)
# Out:
# https://www.googleapis.com/books/v1/volumes?q=intitle%3AInsurgent%2Binauthor%3AVeronica%20Roth&key=AIzaSyC9J5_C1kJfIGejuMPkIKUmnmh2ir-5dok
# https://www.googleapis.com/books/v1/volumes?q=intitle%3AThe%20Revenant%2Binauthor%3AD.%20Kerry%20Prior&key=AIzaSyC9J5_C1kJfIGejuMPkIKUmnmh2ir-5dok
# https://www.googleapis.com/books/v1/volumes?q=intitle%3AFifty%20Shades%20of%20Grey%2Binauthor%3AE.L.%20James&key=AIzaSyC9J5_C1kJfIGejuMPkIKUmnmh2ir-5dok
# https://www.googleapis.com/books/v1/volumes?q=intitle%3AMaze%20Runner%3A%20The%20Scorch%20Trials%2Binauthor%3AJames%20Dashner&key=AIzaSyC9J5_C1kJfIGejuMPkIKUmnmh2ir-5dok
# https://www.googleapis.com/books/v1/volumes?q=intitle%3AGoosebumps%2Binauthor%3AR.%20L.%20Stine&key=AIzaSyC9J5_C1kJfIGejuMPkIKUmnmh2ir-5dok
# https://www.googleapis.com/books/v1/volumes?q=intitle%3ARoom%2Binauthor%3AKyle%20Henry&key=AIzaSyC9J5_C1kJfIGejuMPkIKUmnmh2ir-5dok
# https://www.googleapis.com/books/v1/volumes?q=intitle%3
key=AIzaSyC9J5_C1kJfIGejuMPkIKUmnmh2ir-5dok
# https://www.googleapis.com/books/v1/volumes?q=intitle%3AJohn%20Carter%2Binauthor%3AEdgar%20Rice%20Burroughs&key=AIzaSyC9J5_C1kJfIGejuMPkIKUmnmh2ir-5dok
# https://www.googleapis.com/books/v1/volumes?q=intitle%3AAnna%20Karenina%2Binauthor%3ALeo%20Tolstoy%2C%20Clemence%20Dane&key=AIzaSyC9J5_C1kJfIGejuMPkIKUmnmh2ir-5dok

# %%
not_found
# Out:
# ['The Revenant',
#  'Room',
#  'Dark Places',
#  'Tales of Halloween',
#  'The Amazing Spider-Man 2',
#  '300: Rise of an Empire',
#  'Delirium',
#  'Delirium',
#  'Delirium',
#  'Delirium',
#  'Walled In',
#  'Alice in Wonderland',
#  'Flipped',
#  'Never Let Me Go',
#  "My Girlfriend's Boyfriend",
#  "My Girlfriend's Boyfriend",
#  'In Dreams',
#  'Soul Surfer',
#  'Wuthering Heights',
#  'Little Birds',
#  'Age of the Dragons',
#  'Anna Karenina']

# %% [markdown]
# #### <font color=darkblue>Converting results to DataFrame </font>

# %%
df = pd.DataFrame(book_info, columns=['google_id', 'title', 'author', 'publish_date', 'category', 'pages'])
df
# Out:
#        google_id                                              title  \
# 0   CqyUNAEACAAJ                                          Insurgent
# 1   bg-dAQAACAAJ  Grey - Fifty Shades of Grey von Christian selb...
# 2   Y-qLDQAAQBAJ                                    The Maze Runner
# 3   z2U0CwAAQBAJ                            Goosebumps: Movie Novel
# 4   TdKHvgEACAAJ                                               Room
# ..           ...                                                ...
# 63  ebP-JwAACAAJ                                         Auto Focus
# 64  pxWhzAEACAAJ                                       Forrest Gump
# 65  upodvjM1cFAC                        The Silver Linings Playbook
# 66  GLYsEAAAQBAJ                                       The Sentinel
# 67  xK8RTwEACAAJ                                John Carter of Mars
#
#                                                author publish_date  \
# 0                                     [Veronica Roth]   2015-01-20
# 1                                       [E. L. James]   2015-08-21
# 2                                     [James Dashner]         2015
# 3                                        [R.L. Stine]   2016-01-07
# 4                                     [Emma Donoghue]   2010-09-13
# ..                                                ...          ...
# 63                                 [Robert Graysmith]         2002
# 64                                    [Winston Groom]         2012
# 65                                    [Matthew Quick]   2010-04-27
# 66                          [Lee Child, Andrew Child]   2021-04-27
# 67  [Edgar Rice Burroughs, Frank Schoonover, James...      2010-10
#
#                      category  pages
# 0          [Juvenile Fiction]    592
# 1                         NaN    640
# 2                   [Amnesia]    816
# 3          [Juvenile Fiction]    144
# 4                   [Fiction]    336
# ..                        ...    ...
# 63               [True Crime]    310
# 64                  [Fiction]    228
# 65                  [Fiction]    304
# 66                  [Fiction]    384
# 67  [Comics & Graphic Novels]    462
#
# [68 rows x 6 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#        google_id                                              title  \
# 0   CqyUNAEACAAJ                                          Insurgent
# 1   bg-dAQAACAAJ  Grey - Fifty Shades of Grey von Christian selb...
# 2   Y-qLDQAAQBAJ                                    The Maze Runner
# 3   z2U0CwAAQBAJ                            Goosebumps: Movie Novel
# 4   TdKHvgEACAAJ                                               Room
# ..           ...                                                ...
# 63  ebP-JwAACAAJ                                         Auto Focus
# 64  pxWhzAEACAAJ                                       Forrest Gump
# 65  upodvjM1cFAC                        The Silver Linings Playbook
# 66  GLYsEAAAQBAJ                                       The Sentinel
# 67  xK8RTwEACAAJ                                John Carter of Mars
#
#                                                author publish_date  \
# 0                                     [Veronica Roth]   2015-01-20
# 1                                       [E. L. James]   2015-08-21
# 2                                     [James Dashner]         2015
# 3                                        [R.L. Stine]   2016-01-07
# 4                                     [Emma Donoghue]   2010-09-13
# ..                                                ...          ...
# 63                                 [Robert Graysmith]         2002
# 64                                    [Winston Groom]         2012
# 65                                    [Matthew Quick]   2010-04-27
# 66                          [Lee Child, Andrew Child]   2021-04-27
# 67  [Edgar Rice Burroughs, Frank Schoonover, James...      2010-10
#
#                      category  pages
# 0          [Juvenile Fiction]    592
# 1                         NaN    640
# 2                   [Amnesia]    816
# 3          [Juvenile Fiction]    144
# 4                   [Fiction]    336
# ..                        ...    ...
# 63               [True Crime]    310
# 64                  [Fiction]    228
# 65                  [Fiction]    304
# 66                  [Fiction]    384
# 67  [Comics & Graphic Novels]    462
#
# [68 rows x 6 columns]

# %%
df = DataFrame (df,columns=['title','author','publish_date','category','pages'])
df
# Out:
#                                                 title  \
# 0                                           Insurgent
# 1   Grey - Fifty Shades of Grey von Christian selb...
# 2                                     The Maze Runner
# 3                             Goosebumps: Movie Novel
# 4                                                Room
# ..                                                ...
# 63                                         Auto Focus
# 64                                       Forrest Gump
# 65                        The Silver Linings Playbook
# 66                                       The Sentinel
# 67                                John Carter of Mars
#
#                                                author publish_date  \
# 0                                     [Veronica Roth]   2015-01-20
# 1                                       [E. L. James]   2015-08-21
# 2                                     [James Dashner]         2015
# 3                                        [R.L. Stine]   2016-01-07
# 4                                     [Emma Donoghue]   2010-09-13
# ..                                                ...          ...
# 63                                 [Robert Graysmith]         2002
# 64                                    [Winston Groom]         2012
# 65                                    [Matthew Quick]   2010-04-27
# 66                          [Lee Child, Andrew Child]   2021-04-27
# 67  [Edgar Rice Burroughs, Frank Schoonover, James...      2010-10
#
#                      category  pages
# 0          [Juvenile Fiction]    592
# 1                         NaN    640
# 2                   [Amnesia]    816
# 3          [Juvenile Fiction]    144
# 4                   [Fiction]    336
# ..                        ...    ...
# 63               [True Crime]    310
# 64                  [Fiction]    228
# 65                  [Fiction]    304
# 66                  [Fiction]    384
# 67  [Comics & Graphic Novels]    462
#
# [68 rows x 5 columns]

# %% [markdown]
# #### <font color=darkblue> Further dataset manipulation (removing uneeded columns, brackets, etc) </font>

# %%
df['author'] = df['author'].str.get(0)
df['category'] = df['category'].str.get(0)
df
# Out:
#                                                 title                author  \
# 0                                           Insurgent         Veronica Roth
# 1   Grey - Fifty Shades of Grey von Christian selb...           E. L. James
# 2                                     The Maze Runner         James Dashner
# 3                             Goosebumps: Movie Novel            R.L. Stine
# 4                                                Room         Emma Donoghue
# ..                                                ...                   ...
# 63                                         Auto Focus      Robert Graysmith
# 64                                       Forrest Gump         Winston Groom
# 65                        The Silver Linings Playbook         Matthew Quick
# 66                                       The Sentinel             Lee Child
# 67                                John Carter of Mars  Edgar Rice Burroughs
#
#    publish_date                 category  pages
# 0    2015-01-20         Juvenile Fiction    592
# 1    2015-08-21                      NaN    640
# 2          2015                  Amnesia    816
# 3    2016-01-07         Juvenile Fiction    144
# 4    2010-09-13                  Fiction    336
# ..          ...                      ...    ...
# 63         2002               True Crime    310
# 64         2012                  Fiction    228
# 65   2010-04-27                  Fiction    304
# 66   2021-04-27                  Fiction    384
# 67      2010-10  Comics & Graphic Novels    462
#
# [68 rows x 5 columns]

# %%
movies = moviescheck.rename(columns={'original_title': 'title'})

# %%
movies = movies[['title','writer','director','genres','vote_average','runtime','release_year']]
movies
# Out:
#                              title                      writer  \
# 0                        Insurgent               Veronica Roth
# 1                     The Revenant              D. Kerry Prior
# 2             Fifty Shades of Grey                  E.L. James
# 3   Maze Runner: The Scorch Trials               James Dashner
# 4                       Goosebumps                 R. L. Stine
# ..                             ...                         ...
# 85                    Forrest Gump               Winston Groom
# 86         Silver Linings Playbook               Matthew Quick
# 87                    Jack Reacher                   Lee Child
# 88                     John Carter        Edgar Rice Burroughs
# 89                   Anna Karenina  Leo Tolstoy, Clemence Dane
#
#                        director                                    genres  \
# 0              Robert Schwentke        Adventure|Science Fiction|Thriller
# 1   Alejandro González Iñárritu          Western|Drama|Adventure|Thriller
# 2            Sam Taylor-Johnson                             Drama|Romance
# 3                      Wes Ball           Action|Science Fiction|Thriller
# 4                 Rob Letterman                   Adventure|Horror|Comedy
# ..                          ...                                       ...
# 85              Robert Zemeckis                      Comedy|Drama|Romance
# 86             David O. Russell                      Drama|Comedy|Romance
# 87        Christopher McQuarrie                      Crime|Drama|Thriller
# 88               Andrew Stanton  Action|Adventure|Fantasy|Science Fiction
# 89                   Joe Wright                             Drama|Romance
#
#     vote_average  runtime  release_year
# 0            6.3      119          2015
# 1            7.2      156          2015
# 2            5.3      125          2015
# 3            6.4      132          2015
# 4            6.2      103          2015
# ..           ...      ...           ...
# 85           8.1      142          1994
# 86           6.9      122          2012
# 87           6.2      130          2012
# 88           6.0      132          2012
# 89           6.4      130          2012
#
# [90 rows x 7 columns]

# %% [markdown]
# ### <font color=blue> Merging books and movie dataset </font>

# %%
archquery = df.merge(movies.set_index('writer'), on='title').drop_duplicates(subset=['title'])
archquery = archquery.reset_index(drop = True)

# %%
archquery
# Out:
#                                                 title                 author  \
# 0                                           Insurgent          Veronica Roth
# 1                                     The Maze Runner          James Dashner
# 2                                                Room          Emma Donoghue
# 3                                         Paper Towns             John Green
# 4                                    The Longest Ride        Nicholas Sparks
# 5                                         Dark Places          Gillian Flynn
# 6                                     Z for Zachariah      Robert C. O'Brien
# 7                         The Diary of a Teenage Girl       Phoebe Gloeckner
# 8                            And Then There Were None        Agatha Christie
# 9                                           Gone Girl          Gillian Flynn
# 10                                          The Giver             Lois Lowry
# 11                             The Fault in Our Stars             John Green
# 12                                        Good People           Marcus Sakey
# 13                                      The Boxtrolls         Irena Brignull
# 14                           White Bird in a Blizzard        Laura Kasischke
# 15  Alexander and the Terrible, Horrible, No Good,...          Judith Viorst
# 16                                      The Scribbler        Daniel Schaffer
# 4              George Tillman, Jr.                            Romance|Drama
# 5            Gilles Paquet-Brenner                   Drama|Mystery|Thriller
# 6                      Craig Zobel           Drama|Science Fiction|Thriller
# 7                  Marielle Heller                            Drama|Romance
# 8                   Craig Viveiros                            Mystery|Drama
# 9                    David Fincher                   Mystery|Thriller|Drama
# 10                   Phillip Noyce                    Drama|Science Fiction
# 11                      Josh Boone                            Romance|Drama
# 12               Henrik Ruben Genz                    Thriller|Crime|Action
# 13  Graham Annable|Anthony Stacchi          Animation|Comedy|Family|Fantasy
# 14                     Gregg Araki                           Thriller|Drama
# 15                   Miguel Arteta                            Family|Comedy
# 16                      John Suits                                 Thriller
# 17                        Amy Berg             Thriller|Drama|Crime|Mystery
# 18                 J. Lee Thompson                                  Western
# 19                     Zack Snyder           Action|Mystery|Science Fiction
# 20               Richard Linklater                     Comedy|Drama|Romance
# 21                        Jon Gunn                             Drama|Family
# 22                      Tim Burton                 Family|Fantasy|Adventure
# 23                 Lasse Hallström                        Drama|Romance|War
# 24                      Rob Reiner                     Comedy|Drama|Romance
# 25                   James Mangold                                    Drama
# 26                      Simon West             Crime|Drama|Mystery|Thriller
# 27                 Lasse Hallström                            Drama|Romance
# 28                   David Frankel                            Comedy|Family
# 29                   Peter Sollett               Comedy|Drama|Music|Romance
# 30                   Gregor Jordan    Action|Adventure|Crime|Drama|Thriller
# 31                     Rowan Woods                              Crime|Drama
# 32                   Lone Scherfig                            Drama|Romance
# 33                      Mark Mylod                           Comedy|Romance
# 34                     Tate Taylor                                    Drama
# 35                 Luke Greenfield                     Comedy|Drama|Romance
# 36                   David Frankel                                   Comedy
# 37                  Elliott Lester                    Crime|Action|Thriller
# 38                   Andrea Arnold                            Drama|Romance
# 39                   Adam Shankman                     Drama|Family|Romance
# 40                   Paul Schrader                              Drama|Crime
# 41                 Robert Zemeckis                     Comedy|Drama|Romance
#
#     vote_average  runtime  release_year
# 0            6.3      119          2015
# 1            7.0      113          2014
# 2            8.0      117          2015
# 3            6.2      109          2015
# 4            7.3      128          2015
# 5            5.7      113          2015
# 6            5.5       97          2015
# 7            6.8      102          2015
# 8            7.7      168          2015
# 9            7.9      145          2014
# 10           6.3       94          2014
# 11           7.8      125          2014
# 12           5.2       90          2014
# 13           6.6       97          2014
# 14           6.1       91          2014
# 15           6.2       81          2014
# 16           4.3       88          2014
# 17           5.6       93          2014
# 18           5.6       97          1977
# 19           6.8      162          2009
# 20           6.4      114          2009
# 21           7.0      100          2009
# 22           6.3      108          2010
# 23           6.5      115          2010
# 24           7.2       90          2010
# 25           7.5      127          1999
# 26           5.9      116          1999
# 27           6.3      111          2001
# 28           6.8      115          2008
# 29           6.4       89          2008
# 30           4.3       98          2008
# 31           5.9       95          2008
# 32           6.9      107          2011
# 33           6.2      106          2011
# 34           7.6      146          2011
# 35           6.0      112          2011
# 36           5.4      100          2011
# 37           6.0       97          2011
# 38           5.6      129          2011
# 39           7.3      101          2002
# 40           5.9      104          2002
# 41           8.1      142          1994

# %%
archquery.fillna('-',inplace=True)

# %%
archquery = archquery.drop(['pages'],axis=1)

# %% [markdown]
# ### <font color=blue> Outcome </font>

# %%
archquery[:15]
# Out:
#                           title             author publish_date  \
# 0                     Insurgent      Veronica Roth   2015-01-20
# 1               The Maze Runner      James Dashner         2015
# 2                          Room      Emma Donoghue   2010-09-13
# 3                   Paper Towns         John Green   2018-10-23
# 4              The Longest Ride    Nicholas Sparks   2015-02-24
# 5                   Dark Places      Gillian Flynn      2015-07
# 6               Z for Zachariah  Robert C. O'Brien   2021-06-01
# 7   The Diary of a Teenage Girl   Phoebe Gloeckner         2015
# 8      And Then There Were None    Agatha Christie   2004-05-03
# 9                     Gone Girl      Gillian Flynn   2013-01-01
# 10                    The Giver         Lois Lowry   2014-07-01
# 11       The Fault in Our Stars         John Green         2018
# 12                  Good People       Marcus Sakey   2008-08-14
# 13                The Boxtrolls     Irena Brignull        2014*
# 14     White Bird in a Blizzard    Laura Kasischke   1999-01-13
#
#                       category                        director  \
# 0             Juvenile Fiction                Robert Schwentke
# 1                      Amnesia                        Wes Ball
# 2                      Fiction                Lenny Abrahamson
# 3          Young Adult Fiction                   Jake Schreier
# 4                      Fiction             George Tillman, Jr.
# 5                      Fiction           Gilles Paquet-Brenner
# 6          Young Adult Fiction                     Craig Zobel
# 7      Comics & Graphic Novels                 Marielle Heller
# 8                      Fiction                  Craig Viveiros
# 9                      Fiction                   David Fincher
# 10            Juvenile Fiction                   Phillip Noyce
# 11         Young Adult Fiction                      Josh Boone
# 12                     Fiction               Henrik Ruben Genz
# 13  Civilization, Subterranean  Graham Annable|Anthony Stacchi
# 14                     Fiction                     Gregg Araki
#
#                                      genres  vote_average  runtime  \
# 0        Adventure|Science Fiction|Thriller           6.3      119
# 1   Action|Mystery|Science Fiction|Thriller           7.0      113
# 2                            Drama|Thriller           8.0      117
# 3                     Drama|Mystery|Romance           6.2      109
# 4                             Romance|Drama           7.3      128
# 5                    Drama|Mystery|Thriller           5.7      113
# 6            Drama|Science Fiction|Thriller           5.5       97
# 7                             Drama|Romance           6.8      102
# 8                             Mystery|Drama           7.7      168
# 9                    Mystery|Thriller|Drama           7.9      145
# 10                    Drama|Science Fiction           6.3       94
# 11                            Romance|Drama           7.8      125
# 12                    Thriller|Crime|Action           5.2       90
# 13          Animation|Comedy|Family|Fantasy           6.6       97
# 14                           Thriller|Drama           6.1       91
#
#     release_year
# 0           2015
# 1           2014
# 2           2015
# 3           2015
# 4           2015
# 5           2015
# 6           2015
# 7           2015
# 8           2015
# 9           2014
# 10          2014
# 11          2014
# 12          2014
# 13          2014
# 14          2014

# %% [markdown]
# ### <font color=blue> Searching for a specific title </font>

# %%
df10 = archquery.query("title == 'Alice in Wonderland'", inplace = False)
df10
# Out:
#                   title                 author publish_date  \
# 22  Alice in Wonderland  Joseph Leo Mankiewicz         1933
#
#                                 category    director  \
# 22  Alice in wonderland (Motion picture)  Tim Burton
#
#                       genres  vote_average  runtime  release_year
# 22  Family|Fantasy|Adventure           6.3      108          2010
